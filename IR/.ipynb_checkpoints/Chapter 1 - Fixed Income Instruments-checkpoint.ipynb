# %% [markdown]
# # Fixed income instruments

# %% [markdown]
# ## Interest Rates & Bonds

# %% [markdown]
# 1. Simple definition of an Interest Rate

# %% [markdown]
# 2. Zero Coupon Bond as B(t,T), link with the time value of money and Term Structure

# %% [markdown]
# 3. Spot Rates: Simply compounded & Continous Compouded. Consequence when IR are positive.

# %% [markdown]
# 4. Time value of money, pricing of an amount know at $t<=T$ paying A at $T$. What happens if the payment is totally unknown?

# %% [markdown]
# 5. What happens then to a bond price if at $t<=S<T$ we know the price of B(S,T)?

# %% [markdown]
# ## Forward Rate Agreements

# %% [markdown]
# Regular timeline: $t<=S<T$.
# 1. Payoff of a FRA: $\tau N (L(S,T)-K)$. We need to price it at $t$.

# %% [markdown]
# 2. Link between $\tau L(S,T)$, $B(t,S)$ and $B(t,T)$.

# %% [markdown]
# 3. Link between $K$ and the forward rate $F(t,S,T)$.

# %% [markdown]
# ## Forward interest rates & Bond prices

# %% [markdown]
# Regular timeline: $t<=S<T$.
# 1. What is the price at time $S$ to purchase a T Bond. Define the forward Bond price $FP(t,S,T)$.

# %% [markdown]
# 2. Link between $FP(t,S,T)$ and $F(t,S,T)$.

# %% [markdown]
# 3. Define $R(t,S,T)$, link with $R(t,T)$.

# %% [markdown]
# 4. Link between $f(t,T)$ and $R(t,S,T)$.

# %% [markdown]
# 5. Link between $f(t,T)$ and $r(t)$.

# %% [markdown]
# 6. Bond price with $f(t,T)$ and three popular day count conventions.

# %% [markdown]
# ## Money market account

# %% [markdown]
# 1. Link between $B(t)$ and $r(t)$, value of $B(0)$ and name of this Numeraire.

# %% [markdown]
# ## Coupon bearing bonds

# %% [markdown]
# 1. General set up ie. payment dates $T_{i}$, definition of the coupon of a bond, of the notional. Link with a zero coupon bond.

# %% [markdown]
# 2. Fixed coupon bond and formulae.

# %% [markdown]
# 3. Floating coupon bond and formulae.

# %% [markdown]
# ## Interest rate swap

# %% [markdown]
# 1. Timeline setup : $t<=T_{0}<...<T_{n}$, idea of the princing process. Link between fix rate, payer and receiver swap.

# %% [markdown]
# 2. Definition of payement/settlement dates and of reset dates.

# %% [markdown]
# 3. Definition of forward starting swap and spot starting swap.

# %% [markdown]
# 4. Link with the FRA instrument and with the floating/fixed coupon bearing bonds.

# %% [markdown]
# 5. Definition of the forward swap rate $S_{0,n}(t)$.

# %% [markdown]
# 6. Link between Forward Swap rate, zero coupon bonds and annuity.

# %% [markdown]
# 7. Link between the Forward Swap rate and Forward price of a bond.

# %% [markdown]
# 8. Link between the Forwards Swap rate and the Forward rates.

# %% [markdown]
# ## Yield curve construction

# %% [markdown]
# 1. Link between Forward Swap rates and instantaneous forward rates $f(t,T)$

# %% [markdown]
# ### Yield curve from swap rates

# %% [markdown]
# 2. Building of the long end of the yield curve, the short and middle end is built with forward, futures and FRAs.

# %% [markdown]
# 3. Set up of $K$ Swaps with $n_{1}<...<n_{K}$ maturities and the swap rates $r_{i}$ are known.

# %% [markdown]
# 4. Assumption of the $f(t,T)$ as function of $T$. Linear piece wise in between the differents maturities of our swaps.

# %% [markdown]
# 5. With iteration and root finding methods, find $f_{1}, ... ,f_{n_{K}}$.

# %% [markdown]
# 6. With the forward rates known we can find $B(t,T)$.

# %% [markdown]
# ### Bootstraping the swap rates

# %% [markdown]
# 7. We can keep building the yield curve at a point $n_{i}$ if we know the swap rate $r_{i}$ we can then find $B(t,T_{n_{i}})$.
