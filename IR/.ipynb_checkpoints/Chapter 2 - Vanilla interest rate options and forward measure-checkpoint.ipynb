# %% [markdown]
# # Vanilla interest rate options and forward measure

# %% [markdown]
# ## Change of numeraire

# %% [markdown]
# ## Forward measure

# %% [markdown]
# ## Martingales under forward measure

# %% [markdown]
# ## FRAs and interest rate swaps: the forward measure

# %% [markdown]
# ## Option pricing in the forward measure

# %% [markdown]
# ## Caps and Floors

# %% [markdown]
# ## Swaptions

# %% [markdown]
# ## Implied volatility
